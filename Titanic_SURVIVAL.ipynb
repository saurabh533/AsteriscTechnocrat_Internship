# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabh533/AsteriscTechnocrat_Internship/blob/main/Titanic_SURVIVAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content'

# %%
# !kaggle datasets download -d brendan45774/test-file
# Out:
# ...
#   0% 0.00/11.2k [00:00<?, ?B/s]
# 100% 11.2k/11.2k [00:00<00:00, 23.8MB/s]

# %%
# !unzip test-file.zip -d data
# Out:
# Archive:  test-file.zip
#   inflating: data/tested.csv

# %%
import pandas as pd

# %%
data_titanic = pd.read_csv('/content/data/tested.csv')

# %%
data_titanic['Embarked'][0]
# Out:
# 'Q'

# %%
for i in range(len(data_titanic)):
  if data_titanic['Embarked'][i] =='S':
    data_titanic['Embarked'][i] = 'Southampton'
  elif data_titanic['Embarked'][i] =='Q':
    data_titanic['Embarked'][i] = 'Queenstown'
  else:
    data_titanic['Embarked'][i] = 'Cherbourg'
# Out:
# <ipython-input-357-3bbc273f1777>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_titanic['Embarked'][i] = 'Queenstown'
# <ipython-input-357-3bbc273f1777>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_titanic['Embarked'][i] = 'Southampton'
# <ipython-input-357-3bbc273f1777>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_titanic['Embarked'][i] = 'Cherbourg'

# %%
data_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data_titanic[data_titanic['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data_titanic['Embarked'].value_counts()
# Out:
# Southampton    270
# Cherbourg      102
# Queenstown      46
# Name: Embarked, dtype: int64

# %% [markdown]
# **DESCRIPTIVE STATISTICS**

# %%
import matplotlib.pyplot as plt

# %%
categories = ['male','female']
male_count = len(data_titanic[data_titanic['Sex']=='male'])
female_count = len(data_titanic[data_titanic['Sex']=='female'])
population = [male_count,female_count]

# %%
plt.bar(categories, population, color=['blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Population')
plt.title('Male vs Female Population')
plt.show()
plt.savefig('population_ratio')

# %%
#survival rate in titanic

# %%
survived=data_titanic['Survived'].value_counts()[1]

# %%
died = data_titanic['Survived'].value_counts()[0]

# %%
plt.pie([survived,died],labels=['survived','died'],colors=['green','red'])
plt.show()
plt.savefig('survival_ratio')

# %%
sibsp_counts = data_titanic['SibSp'].value_counts().sort_index()
bar_colors = ['skyblue', 'salmon', 'lightgreen', 'purple', 'orange', 'pink', 'cyan', 'grey']
plt.bar(sibsp_counts.index, sibsp_counts.values,color=bar_colors)
plt.xlabel('Number of Siblings/Spouses')
plt.ylabel('Passenger Count')
plt.title('Distribution of Siblings/Spouses Aboard')
plt.xticks(sibsp_counts.index)
plt.show()
plt.savefig('count of sibling')

# %%
#Average age of death and survival

# %%
import numpy as np

# %%
Average_age_survived = np.average(data_titanic[data_titanic['Survived']==1].dropna()['Age'])

# %%
Average_age_death = np.average(data_titanic[data_titanic['Survived']==0].dropna()['Age'])

# %%
categories = ['Average_age_survived','Average_age_death']

# %%
plt.bar(categories,[Average_age_survived,Average_age_death],color=['green','red'])
plt.show()
plt.savefig('survival_rate')

# %%
children_count=data_titanic['Parch'].value_counts().sort_index()
categories1 = children_count.index
value = children_count.values
plt.bar(categories1,value,color=['blue','salmon'])
plt.xlabel('Number of distinct children')
plt.show()
plt.savefig('children_count')

# %%
embarked_counts = data_titanic['Embarked'].value_counts()

# Define custom colors for the bars
bar_colors = ['skyblue', 'salmon', 'lightgreen']

# Create a bar plot for Embarked
plt.bar(embarked_counts.index, embarked_counts.values, color=bar_colors)
plt.xlabel('Port of Embarkation')
plt.ylabel('Passenger Count')
plt.title('Distribution of Passengers by Port of Embarkation')
plt.show()
plt.savefig('Boarding_station')

# %%
titanic_class = data_titanic['Pclass'].value_counts().sort_index()
categories3 = titanic_class.index
values = titanic_class.values


pie_colors = ['lightgreen', 'purple', 'orange']

plt.pie(values, labels=categories3, colors=pie_colors, autopct='%1.1f%%', startangle=140)
plt.title('Passenger Class Distribution')
plt.axis('equal')
plt.show()
plt.savefig('classes')

# %%
data_titanic['Name'][1]
# Out:
# 'Wilkes, Mrs. James (Ellen Needs)'

# %%
data_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data_titanic['Age'].isna().sum()
# Out:
# 86

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
# Select continuous columns (you might need to adjust this list based on your dataset)
continuous_columns = ['Age', 'Fare']

# Set the style of seaborn
sns.set(style="whitegrid")

# Create histograms for all continuous columns using a loop
for column in continuous_columns:
    if column == 'Fare':
        plt.figure(figsize=(10, 4))  # Set the figure size
    sns.histplot(data=data_titanic, x=column, bins=20, kde=True, color='skyblue')

    # Add labels and title
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column} in Titanic Dataset')

    # Show the plot
    plt.show()

# %%
data_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
X_train = data_titanic[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

# %%
for i in X_train.columns:
  sum = X_train[i].isna().sum()
  if sum>0:
      mean = np.mean(X_train[i])
      X_train[i].fillna(mean,inplace=True)
# Out:
# <ipython-input-384-9e175561cf81>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[i].fillna(mean,inplace=True)

# %%
X_train
# Out:
#      Pclass     Sex       Age  SibSp  Parch      Fare     Embarked
# 0         3    male  34.50000      0      0    7.8292   Queenstown
# 1         3  female  47.00000      1      0    7.0000  Southampton
# 2         2    male  62.00000      0      0    9.6875   Queenstown
# 3         3    male  27.00000      0      0    8.6625  Southampton
# 4         3  female  22.00000      1      1   12.2875  Southampton
# ..      ...     ...       ...    ...    ...       ...          ...
# 413       3    male  30.27259      0      0    8.0500  Southampton
# 414       1  female  39.00000      0      0  108.9000    Cherbourg
# 415       3    male  38.50000      0      0    7.2500  Southampton
# 416       3    male  30.27259      0      0    8.0500  Southampton
# 417       3    male  30.27259      1      1   22.3583    Cherbourg
#
# [418 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

X_train['Sex'] = label_encoder.fit_transform(X_train['Sex'])

# Encode 'Embarked' column
X_train['Embarked'] = label_encoder.fit_transform(X_train['Embarked'])
# Out:
# <ipython-input-386-dcec742f73df>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Sex'] = label_encoder.fit_transform(X_train['Sex'])
# <ipython-input-386-dcec742f73df>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Embarked'] = label_encoder.fit_transform(X_train['Embarked'])

# %%
np.isinf(X_train).sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
X_train
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0         3    1  34.50000      0      0    7.8292         1
# 1         3    0  47.00000      1      0    7.0000         2
# 2         2    1  62.00000      0      0    9.6875         1
# 3         3    1  27.00000      0      0    8.6625         2
# 4         3    0  22.00000      1      1   12.2875         2
# ..      ...  ...       ...    ...    ...       ...       ...
# 413       3    1  30.27259      0      0    8.0500         2
# 414       1    0  39.00000      0      0  108.9000         0
# 415       3    1  38.50000      0      0    7.2500         2
# 416       3    1  30.27259      0      0    8.0500         2
# 417       3    1  30.27259      1      1   22.3583         0
#
# [418 rows x 7 columns]

# %%
X_train['Age'] = X_train['Age'].astype(int)
X_train['Fare'] = X_train['Age'].astype(int)
# Out:
# <ipython-input-389-316b2ae05166>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Age'] = X_train['Age'].astype(int)
# <ipython-input-389-316b2ae05166>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Fare'] = X_train['Age'].astype(int)

# %%
X_train['Fare'][330]
# Out:
# 48

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y, test_size=0.2, random_state=1)

# %%
LR = LogisticRegression(solver='liblinear', max_iter=200)
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
LRAcc = accuracy_score(y_pred,y_test)
print('Logistic regression accuracy: {:.2f}%'.format(LRAcc*100))
# Out:
# Logistic regression accuracy: 100.00%

# %%
X_train.dtypes
# Out:
# Pclass      int64
# Sex         int64
# Age         int64
# SibSp       int64
# Parch       int64
# Fare        int64
# Embarked    int64
# dtype: object
